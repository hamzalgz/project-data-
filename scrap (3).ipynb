# %% [markdown]
# # library

# %%
import csv
import pandas as pd
from getpass import getpass
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver import Chrome

# %% [markdown]
# # connecting with google chrome

# %%
driver=Chrome(r'C:\Users\hamza lagramez\Desktop\chromedriver_win32\chromedriver.exe')

# %%
driver.get('https://www.twitter.com/login')

# %% [markdown]
# # enter ur mail

# %%
username=driver.find_element_by_xpath('//*[@id="react-root"]/div/div/div[2]/main/div/div/div[2]/form/div/div[1]/label/div/div[2]/div/input')
username.send_keys('hamzalagramez7@gmail.com')

# %% [markdown]
# # enter ur password

# %%
passwrd=getpass()
# Out:
# ········

# %%
psswrd=driver.find_element_by_xpath('//*[@id="react-root"]/div/div/div[2]/main/div/div/div[2]/form/div/div[2]/label/div/div[2]/div/input')
psswrd.send_keys(passwrd)

# %%
psswrd.send_keys(Keys.RETURN)

# %% [markdown]
# # tag that u want

# %%
search_bar=driver.find_element_by_xpath('//input[@data-testid="SearchBox_Search_Input"]')
search_bar.send_keys('#isreal')

# %%
search_bar.send_keys(Keys.RETURN)

# %% [markdown]
# # enter ur post that u want

# %%
#dir post li 3ajbakk
driver.get('https://twitter.com/nytimes/status/1393707781006544903')

# %%
def scraping_tweet(card):
    usernam=card.find_element_by_xpath('.//span').text
    try:
        date=card.find_element_by_xpath('.//time').get_attribute('datetime')
        reply_cnt = card.find_element_by_xpath('.//div[@data-testid="reply"]').text
        retweet_cnt = card.find_element_by_xpath('.//div[@data-testid="retweet"]').text
        like_cnt = card.find_element_by_xpath('.//div[@data-testid="like"]').text
        text =card.find_element_by_xpath('.//div[2]/div[2]/div[2]/div[1]').text
    except NoSuchElementException:
        return 0
    try:
        text =card.find_element_by_xpath('.//div[2]/div[2]/div[2]/div[1]').text
    except NoSuchElementException:
        return NAN
        
    tweet=(usernam, date, reply_cnt, retweet_cnt,like_cnt,text  )
    return tweet

# %%
from time import sleep
from ast import literal_eval
comments = []
tweet_ids = set()

last_position = driver.execute_script("return window.pageYOffset;")
scrolling = True

while scrolling:
    page_cards = driver.find_elements_by_xpath('//div[@data-testid="tweet"]')
    #nb = page_cards[0].find_element_by_xpath('.//div[@data-testid="retweet"]').text
    for card in page_cards:
        tweet = scraping_tweet(card)
        if tweet:
            tweet_id=''.join(tweet)
            if tweet_id not in tweet_ids:
                tweet_ids.add(tweet_id)
                comments.append(tweet)

            
    scroll_attempt = 0
    while True:
        # check scroll position
        driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
        sleep(3)
        curr_position = driver.execute_script("return window.pageYOffset;")
        if last_position == curr_position:
            scroll_attempt += 1
            
            # end of scroll region
            if scroll_attempt < 4:
                sleep(3)
            else:
                
                if scroll_attempt > 4:
                    scrolling = False
                    break
                else:
                    driver.find_element_by_xpath('//*[@id="react-root"]/div/div/div[2]/main/div/div/div/div/div/div[2]/div/section/div/div/div[13]').click()
                    sleep(3)
        else:
            last_position = curr_position
            break
# Out:
# ---------------------------------------------------------------------------
# ElementNotInteractableException           Traceback (most recent call last)
# <ipython-input-318-3eabc7a3e8b5> in <module>
#      37                     break
#      38                 else:
# ---> 39                     driver.find_element_by_xpath('//*[@id="react-root"]/div/div/div[2]/main/div/div/div/div/div/div[2]/div/section/div/div/div[13]').click()
#      40                     sleep(3)
#      41         else:
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      78     def click(self):
#      79         """Clicks the element."""
# ---> 80         self._execute(Command.CLICK_ELEMENT)
#      81
#      82     def submit(self):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# ElementNotInteractableException: Message: element not interactable
#   (Session info: chrome=81.0.4044.122)

# %%
# close the web driver
driver.close()

# %%
df=pd.DataFrame(comments)

# %%
df.shape
# Out:
# (80, 6)

# %%
df.head(30)
# Out:
#                                  0                         1  2 3   4  \
# 0                Jedi, Interrupted  2021-05-15T23:20:55.000Z  2     6
# 1                             ylil  2021-05-15T23:21:31.000Z        6
# 2                    Premium Steve  2021-05-15T23:21:40.000Z  1     6
# 3                        Tom Craft  2021-05-15T23:22:39.000Z  3     1
# 4                         Teixeira  2021-05-15T23:22:47.000Z  6     3
# 5                Clare Boothe Luce  2021-05-15T23:23:46.000Z  3     3
# 6                      Amy Bayless  2021-05-15T23:23:52.000Z  1     1
# 7                               cd  2021-05-15T23:24:32.000Z  1     3
# 8                  Kathryn Rippley  2021-05-15T23:24:57.000Z
# 9                            ademm  2021-05-15T23:25:30.000Z
# 10                           ademm  2021-05-15T23:26:20.000Z
# 11                           ademm  2021-05-15T23:27:00.000Z
# 12                  Patrick Whalen  2021-05-15T23:27:45.000Z
# 13                   Emma Chiswell  2021-05-15T23:28:40.000Z
# 14                      José Alves  2021-05-15T23:30:17.000Z        1
# 15                 reilly o’reilly  2021-05-15T23:32:45.000Z
# 16                           kevin  2021-05-15T23:32:56.000Z  1     2
# 17                             rpj  2021-05-15T23:33:12.000Z  2
# 18                Painel Rio Verde  2021-05-15T23:33:29.000Z  1    10
# 19                            Orin  2021-05-15T23:37:53.000Z  3     3
# 20                             jão  2021-05-15T23:38:28.000Z        1
# 21                chad thundercock  2021-05-15T23:40:18.000Z
# 22                   Forevertonian  2021-05-15T23:40:26.000Z
# 23                        benjamin  2021-05-15T23:48:09.000Z
# 24                               M  2021-05-15T23:56:36.000Z
# 25  TXBlueBanshee46TheSunisShining  2021-05-16T00:03:06.000Z        1
# 26                         gökyüzü  2021-05-16T00:04:58.000Z
# 27                 Garrett Moffitt  2021-05-16T00:08:28.000Z  1     1
# 28                   Garage Dragon  2021-05-16T00:09:17.000Z
# 29                kevin kosanovich  2021-05-16T00:22:34.000Z
#
#                                                     5
# 0   Yes, this is definitely something that only ha...
# 1                     ok to da boomer that wrote this
# 2              I think this is plagiarizing Herodotus
# 3                           They need teen abortions.
# 4      Imagine thinking being a teenager is difficult
# 5   You have one job when raising a teen: keep the...
# 6   It's always been draining being the parent of ...
# 7        A teen has a King size bed? Not in my house!
# 8                                    Tell me about it
# 9   Jerusalem is the land of Palestinians as well ...
# 10                 Give voice to Jerusalem. #HearGaza
# 11  Please do not remain silent to the persecution...
# 12                               awesome. Can't wait.
# 13          You're the ones who made them like this!
# 14                           La verdad es que si ¡¡¡¡
# 15                          its always been like that
# 16  I remember when I was a teenager weed was hard...
# 17                     When did everyone get so soft?
# 18  Yes, the problem is always the teenagers; not ...
# 19  Why must the New York Times portray things in ...
# 20  so... don't be a parent...? I mean condoms and...
# 21                                            Its not
# 22  Did you get this photo by searching step-moms ...
# 23                             Jfc let’s mute the NYT
# 24  well maybe....and hear me out\n\nperhaps, we s...
# 25  What crisis? My son told me remote learning wa...
# 26                      turn your eyes here #HearGaza
# 27  Teens are in crisis because parent whine at th...
# 28                                 Evergreen article.
# 29  Has the times always been the \n@CBS\n of news...

# %%
#wa 4itamn 5alass tacoss HHHHHHHHHH

# %%
df.to_csv('scrapi.csv')
